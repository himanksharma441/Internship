# %% [markdown]
# # Zomato Restaurant Project

# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Project Description
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
#
# Data Storage:
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
# Country_code.csv contains two variables:
# • Country code
# • Country name
#
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
# • Restaurant Id: Unique id of every restaurant across various cities of the world
# • Restaurant Name: Name of the restaurant
# • Country Code: Country in which restaurant is located
# • City: City in which restaurant is located
# • Address: Address of the restaurant
# • Locality: Location in the city
# • Locality Verbose: Detailed description of the locality
# • Longitude: Longitude coordinate of the restaurant&#39;s location
# • Latitude: Latitude coordinate of the restaurant&#39;s location
# • Cuisines: Cuisines offered by the restaurant
# • Average Cost for two: Cost for two people in different currencies ��
# • Currency: Currency of the country
# • Has Table booking: yes/no
# • Has Online delivery: yes/ no
# • Is delivering: yes/ no
# • Switch to order menu: yes/no
# • Price range: range of price of food
# • Aggregate Rating: Average rating out of 5
# • Rating color: depending upon the average rating color
# • Rating text: text on the basis of rating of rating
# • Votes: Number of ratings casted by people
#
# Problem statement : In this dataset predict 2 things –
# 1) Average Cost for two
# 2) Price range
#
#
# Hint : Use pandas merge operation -- pd.merge (df1,df2) to combine two datasets

# %% [markdown]
# # Import Dataset

# %%
df1=pd.read_csv("zomato.csv")
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df2=pd.read_csv("Country-Code1.csv")
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
# Merging the Two Dataframe 
df=pd.merge(df1,df2)
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730              NamlÛ± Gurme           208  ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208  ÛÁstanbul
# 9548        5915807                     Huqqa           208  ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208  ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address     Locality  \
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...     Karakí_y
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...    Koôuyolu
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karakí_y, ÛÁstanbul  28.977392  41.022793
# ...

# %%
df.sample(5)
# Out:
#       Restaurant ID Restaurant Name  Country Code       City  \
# 1541       17953932        Pita Pan             1    Gurgaon
# 2578       18258757    Bella Italia             1  New Delhi
# 9363        7601102      Chaophraya           215  Edinburgh
# 8978       18430582    Bake Walkers             1      Noida
# 2955       18311930         Cuisine             1  New Delhi
#
#                                                 Address           Locality  \
# 1541  4-B, Food Court, 3rd Floor, MGF Metropolitan M...            MG Road
# 2578  Ground Floor, MLCP, IGI Terminal 3, Aerocity, ...           Aerocity
# 9363  4th Floor, 33 Castle Street, New Town, Edinbur...           New Town
# 8978                            BH-39, Sector 72, Noida          Sector 72
# 2955  Rockland Inn, B-207, Block B, Outer Ring Road,...  Chittaranjan Park
#
#                   Locality Verbose  Longitude   Latitude  \
# 1541              MG Road, Gurgaon  77.080325  28.480509
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (9551, 22)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# there are some few null value in Cuisines

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# Droping the null values
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.describe().transpose()
# Out:
#                        count          mean           std         min  \
# Restaurant ID         9542.0  9.043301e+06  8.791967e+06   53.000000
# Country Code          9542.0  1.817921e+01  5.645160e+01    1.000000
# Longitude             9542.0  6.427500e+01  4.119760e+01 -157.948486
# Latitude              9542.0  2.584853e+01  1.101009e+01  -41.330428
# Average Cost for two  9542.0  1.200326e+03  1.612874e+04    0.000000
# Price range           9542.0  1.804968e+00  9.055631e-01    1.000000
# Aggregate rating      9542.0  2.665238e+00  1.516588e+00    0.000000
# Votes                 9542.0  1.567721e+02  4.302033e+02    0.000000
#
#                                 25%           50%           75%           max
# Restaurant ID         301931.250000  6.002726e+06  1.835260e+07  1.850065e+07
# Country Code               1.000000  1.000000e+00  1.000000e+00  2.160000e+02
# Longitude                 77.081565  7.719203e+01  7.728204e+01  1.748321e+02
# ...

# %%
df['Price range'].value_counts()
# Out:
# 1    4438
# 2    3113
# 3    1405
# 4     586
# Name: Price range, dtype: int64

# %%
# Countplot of Price Range
sns.countplot(x='Price range',data=df)
# Out:
# <Axes: xlabel='Price range', ylabel='count'>

# %%
df['Aggregate rating'].value_counts()
# Out:
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     495
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     399
# 2.9     381
# 3.9     332
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     143
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      41
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64

# %%
# Countplot of Aggregate rating
plt.figure(figsize=(15,7))
sns.countplot(x='Aggregate rating',data=df)
plt.show()

# %%
df['Country'].value_counts()
# Out:
# India             8652
# United States      425
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
# Countplot of Country
plt.figure(figsize=(20,5))
sns.countplot(x='Country',data=df)
plt.show()

# %%
df['Average Cost for two'].value_counts()
# Out:
# 500       900
# 300       897
# 400       857
# 200       687
# 600       652
#          ...
# 8000        1
# 2350        1
# 150000      1
# 70000       1
# 545         1
# Name: Average Cost for two, Length: 140, dtype: int64

# %%
# Countplot of Average Cost for two
plt.figure(figsize=(18,9))
sns.countplot(x='Average Cost for two',data=df)
plt.show()

# %%
# Countplot of Rating color
plt.figure(figsize=(15,6))
sns.countplot(x='Rating color',data=df)
plt.show()

# %%
# Countplot of Has Table booking
print(df['Has Table booking'].value_counts())
plt.figure(figsize=(10,5))
sns.countplot(x='Has Table booking',data=df)
# Out:
# No     8384
# Yes    1158
# Name: Has Table booking, dtype: int64
# <Axes: xlabel='Has Table booking', ylabel='count'>

# %%
# Countplot of Has Online delivery
print(df['Has Online delivery'].value_counts())
plt.figure(figsize=(10,5))
sns.countplot(x='Has Online delivery',data=df)
# Out:
# No     7091
# Yes    2451
# Name: Has Online delivery, dtype: int64
# <Axes: xlabel='Has Online delivery', ylabel='count'>

# %%
# Countplot of Is delivering now
print(df['Is delivering now'].value_counts())
plt.figure(figsize=(10,5))
sns.countplot(x='Is delivering now',data=df)
# Out:
# No     9508
# Yes      34
# Name: Is delivering now, dtype: int64
# <Axes: xlabel='Is delivering now', ylabel='count'>

# %%
# Top 3 countries that use Zomato
plt.pie(df['Country'].value_counts().values[:3], labels=df['Country'].value_counts().index[:3])
# Out:
# ([<matplotlib.patches.Wedge at 0x182a39b1290>,
# ...
#  [Text(-1.083531565863807, 0.189629496061996, 'India'),
#   Text(1.0779194567879458, -0.21929351262173782, 'United States'),
#   Text(1.0995857034695016, -0.03018742661244155, 'United Kingdom')])

# %%
# Piechart for most ordered cuisines(TOP 10)
plt.pie(df['Cuisines'].value_counts().values[:10], labels=df['Cuisines'].value_counts().index[:10])
# Out:
# ([<matplotlib.patches.Wedge at 0x182aa16e710>,
# ...
#  [Text(0.7383739846958008, 0.8153550507137645, 'North Indian'),
#   Text(-0.5794679314239953, 0.9349956772366362, 'North Indian, Chinese'),
#   Text(-1.067309479615702, 0.26617752482593154, 'Chinese'),
#   Text(-1.0185984499802057, -0.4152796620326146, 'Fast Food'),
#   Text(-0.5935788454809928, -0.9261015895664211, 'North Indian, Mughlai'),
#   Text(-0.005887079599915552, -1.0999842463843672, 'Cafe'),
#   Text(0.4842062514572988, -0.9876964645323336, 'Bakery'),
#   Text(0.808736477166136, -0.7456174022251013, 'North Indian, Mughlai, Chinese'),
#   Text(1.0055375294202338, -0.44597564611473206, 'Bakery, Desserts'),
#   Text(1.090298995560443, -0.14576728123927227, 'Street Food')])

# %%
#Create a piechart to show the top city distribution
plt.pie(df['City'].value_counts().values[:5], labels=df['City'].value_counts().index[:5])
# Out:
# ([<matplotlib.patches.Wedge at 0x182aa25ce50>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')])

# %%
# Country & Currency
df[['Country','Currency']].groupby(['Country','Currency']).size().reset_index().rename(columns={0:'Currency count'})
# Out:
#            Country                Currency  Currency count
# 0        Australia               Dollar($)              24
# 1           Brazil      Brazilian Real(R$)              60
# 2           Canada               Dollar($)               4
# 3            India      Indian Rupees(Rs.)            8652
# 4        Indonesia  Indonesian Rupiah(IDR)              21
# 5      New Zealand           NewZealand($)              40
# 6      Phillipines        Botswana Pula(P)              22
# 7            Qatar         Qatari Rial(QR)              20
# 8        Singapore               Dollar($)              20
# 9     South Africa                 Rand(R)              60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)              20
# 11          Turkey        Turkish Lira(TL)              34
# 12             UAE      Emirati Diram(AED)              60
# 13  United Kingdom              Pounds(Œ£)              80
# 14   United States               Dollar($)             425

# %%
# Relation between Country & Price range
plt.figure(figsize=(12,7))
sns.countplot(x='Price range', hue='Country', data=df)
# Out:
# <Axes: xlabel='Price range', ylabel='count'>

# %%
# Relation between Average Cost for two & Price range
plt.figure(figsize=(18,6))
sns.countplot(x='Average Cost for two', hue='Price range', data=df)
# Out:
# <Axes: xlabel='Average Cost for two', ylabel='count'>

# %%
# Droping unnecessary column
df.drop(['Restaurant ID', 'Restaurant Name', 'Address', 'Locality', 'Locality Verbose', 
         'Cuisines', 'Switch to order menu', 'Is delivering now'],axis=1,inplace=True)

# %% [markdown]
# # Encoding categorical data

# %%
Category=['City', 'Currency', 'Has Table booking','Has Online delivery', 'Rating color', 'Rating text', 'Country']

# %%
# Using Label Encoder on categorical variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Category:
    df[i] = le.fit_transform(df[i])

# %%
df.sample(3)
# Out:
#       Country Code  City  Longitude   Latitude  Average Cost for two  \
# 7283             1    87  77.162671  28.706672                   500
# 2646             1    87  77.310323  28.657855                   600
# 5780             1    87   0.000000   0.000000                   120
#
#       Currency  Has Table booking  Has Online delivery  Price range  \
# 7283         4                  0                    0            2
# 2646         4                  0                    0            2
# 5780         4                  0                    0            1
#
#       Aggregate rating  Rating color  Rating text  Votes  Country
# 7283               0.0             4            3      0        3
# 2646               2.9             2            0      4        3
# 5780               3.0             2            0      7        3

# %%
plt.figure(figsize=(30,30), facecolor='white')
plotnumber =1
for column in df:
    if plotnumber <=15:
        ax = plt.subplot(5,4,plotnumber)
        sns.violinplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# # Outliers Detection and Removal

# %%
df.plot(kind='box',subplots=True ,layout=(6,4) ,figsize=(18,18))
# Out:
# Country Code                Axes(0.125,0.77;0.168478x0.11)
# City                     Axes(0.327174,0.77;0.168478x0.11)
# Longitude                Axes(0.529348,0.77;0.168478x0.11)
# Latitude                 Axes(0.731522,0.77;0.168478x0.11)
# Average Cost for two       Axes(0.125,0.638;0.168478x0.11)
# Currency                Axes(0.327174,0.638;0.168478x0.11)
# Has Table booking       Axes(0.529348,0.638;0.168478x0.11)
# Has Online delivery     Axes(0.731522,0.638;0.168478x0.11)
# Price range                Axes(0.125,0.506;0.168478x0.11)
# Aggregate rating        Axes(0.327174,0.506;0.168478x0.11)
# Rating color            Axes(0.529348,0.506;0.168478x0.11)
# Rating text             Axes(0.731522,0.506;0.168478x0.11)
# Votes                      Axes(0.125,0.374;0.168478x0.11)
# Country                 Axes(0.327174,0.374;0.168478x0.11)
# dtype: object

# %% [markdown]
# # Outliers removal using Zscore method

# %%
# Removing Outliers using Z score Method
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#       Country Code      City  Longitude  Latitude  Average Cost for two  \
# 0         2.547817  0.200637   1.377641  1.024849              0.006221
# 1         2.547817  0.200637   1.377315  1.025915              0.000020
# 2         2.547817  0.112841   1.378352  1.023399              0.173592
# 3         2.547817  0.112841   1.378344  1.023043              0.018581
# 4         2.547817  0.112841   1.378369  1.023122              0.018581
# ...            ...       ...        ...       ...                   ...
# 9546      3.362717  2.696627   0.856833  1.378286              0.069465
# 9547      3.362717  2.696627   0.855281  1.377110              0.067915
# 9548      3.362717  2.696627   0.855443  1.381285              0.063885
# 9549      3.362717  2.696627   0.855410  1.381482              0.066985
# 9550      3.362717  2.696627   0.855652  1.374833              0.071015
#
#       Currency  Has Table booking  Has Online delivery  Price range  \
# ...

# %%
threshold=3
print(np.where(z<3))
df3=df[(z<3).all(axis=1)]
# Out:
# (array([   0,    0,    0, ..., 9541, 9541, 9541], dtype=int64), array([ 0,  1,  2, ..., 11, 12, 13], dtype=int64))

# %%
df3
# Out:
#       Country Code  City   Longitude   Latitude  Average Cost for two  \
# 544            184   117  103.860005   1.282661                   300
# 545            184   117  103.859422   1.285477                   270
# 546            184   117  103.840360   1.279420                   500
# 547            184   117  103.841669   1.280503                    80
# 548            184   117  103.853605   1.293221                   430
# ...            ...   ...         ...        ...                   ...
# 9271             1   133   83.361377  17.764287                   600
# 9272             1   133    0.000000   0.000000                   400
# 9273             1   133   83.315281  17.719539                   600
# 9274             1   133   83.336840  17.721182                  1500
# 9275             1   133   83.314942  17.721119                  1400
#
#       Currency  Has Table booking  Has Online delivery  Price range  \
# ...

# %%
df=df3.copy()
df.shape
# Out:
# (8441, 14)

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# Country Code            20.474407
# City                    -1.379869
# Longitude               -3.751598
# Latitude                -3.252239
# Average Cost for two     3.718110
# Currency               -20.474407
# Has Table booking        2.274963
# Has Online delivery      0.985035
# Price range              1.051111
# Aggregate rating        -0.865608
# Rating color             0.102249
# Rating text              0.425134
# Votes                    3.718438
# Country                 20.474407
# dtype: float64

# %%
df.hist(bins=30,figsize=(30,15))
# Out:
# array([[<Axes: title={'center': 'Country Code'}>,
#         <Axes: title={'center': 'City'}>,
#         <Axes: title={'center': 'Longitude'}>,
#         <Axes: title={'center': 'Latitude'}>],
#        [<Axes: title={'center': 'Average Cost for two'}>,
#         <Axes: title={'center': 'Currency'}>,
#         <Axes: title={'center': 'Has Table booking'}>,
#         <Axes: title={'center': 'Has Online delivery'}>],
#        [<Axes: title={'center': 'Price range'}>,
#         <Axes: title={'center': 'Aggregate rating'}>,
#         <Axes: title={'center': 'Rating color'}>,
#         <Axes: title={'center': 'Rating text'}>],
#        [<Axes: title={'center': 'Votes'}>,
#         <Axes: title={'center': 'Country'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# Using logp1 method
for i in df:
    if df.skew().loc[i]>0.55:
        df[i]=np.log1p(df[i])

# %% [markdown]
# # Correlation

# %%
cor=df.corr()
cor
# Out:
#                       Country Code      City  Longitude  Latitude  \
# Country Code              1.000000  0.105099   0.083573 -0.174272
# City                      0.105099  1.000000   0.009146  0.032233
# Longitude                 0.083573  0.009146   1.000000  0.902029
# Latitude                 -0.174272  0.032233   0.902029  1.000000
# Average Cost for two     -0.096352 -0.101829   0.043050  0.020256
# Currency                 -1.000000 -0.105099  -0.083573  0.174272
# Has Table booking        -0.018379 -0.018022   0.062609  0.068282
# Has Online delivery      -0.030324 -0.030940   0.139823  0.160952
# Price range               0.098316 -0.085850   0.051662 -0.042693
# Aggregate rating          0.035242 -0.071188   0.178058  0.091747
# Rating color             -0.000851  0.068384  -0.085248 -0.058825
# Rating text              -0.002321 -0.043524  -0.107608 -0.154687
# Votes                     0.011437 -0.069183   0.189558  0.088329
# ...

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Machine Learning Model Building

# %% [markdown]
# # Average Cost for two

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

# %%
x=df.drop(['Average Cost for two'], axis=1)
y=df['Average Cost for two']

# %%
x
# Out:
#       Country Code  City   Longitude   Latitude  Currency  Has Table booking  \
# 544       5.220356   117  103.860005   1.282661         2                0.0
# 545       5.220356   117  103.859422   1.285477         2                0.0
# 546       5.220356   117  103.840360   1.279420         2                0.0
# 547       5.220356   117  103.841669   1.280503         2                0.0
# 548       5.220356   117  103.853605   1.293221         2                0.0
# ...            ...   ...         ...        ...       ...                ...
# 9271      0.693147   133   83.361377  17.764287         4                0.0
# 9272      0.693147   133    0.000000   0.000000         4                0.0
# 9273      0.693147   133   83.315281  17.719539         4                0.0
# 9274      0.693147   133   83.336840  17.721182         4                0.0
# 9275      0.693147   133   83.314942  17.721119         4                0.0
#
# ...

# %%
y
# Out:
# 544     5.707110
# 545     5.602119
# 546     6.216606
# 547     4.394449
# 548     6.066108
#           ...
# 9271    6.398595
# 9272    5.993961
# 9273    6.398595
# 9274    7.313887
# 9275    7.244942
# Name: Average Cost for two, Length: 8441, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, random_state=42, test_size=.20)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (6752, 13)
# (6752,)
# (1689, 13)
# (1689,)

# %% [markdown]
# # Using Linear Regression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-3.77447823e-01, -5.37161977e-04, -4.38456901e-03,  1.07904806e-02,
#         1.66746379e-01,  3.63935548e-01,  7.83776949e-02,  1.98758033e+00,
#        -2.48400534e-03, -7.93794337e-03, -4.75325256e-03,  3.12988819e-02,
#        -6.76098384e-02])

# %%
lr.intercept_
# Out:
# 3.898762104266422

# %%
lrpred=lr.predict(x_test)
print("Predicted Value", lrpred)
print("Actual Value", y_test)
# Out:
# Predicted Value [7.10332228 5.48752523 5.46607083 ... 5.67319655 5.48752383 6.92887409]
# Actual Value 943     6.908755
# 3391    5.303305
# 4624    5.707110
# 916     6.111467
# 5117    6.398595
#           ...
# 2134    6.216606
# 2745    6.216606
# 2566    5.993961
# 6082    5.303305
# 8319    7.244942
# Name: Average Cost for two, Length: 1689, dtype: float64

# %%
print('Mean Squared Error:', mse(y_test, lrpred))
print('Mean Absolute Error:', mae(y_test, lrpred))
print('Root Mean Squared Error:', np.sqrt(mse(y_test, lrpred)))
print('R2 Score:', r2_score(y_test, lrpred))
# Out:
# Mean Squared Error: 0.11110401017509604
# Mean Absolute Error: 0.25328503797289914
# Root Mean Squared Error: 0.33332268175912666
# R2 Score: 0.7960657586543342

# %% [markdown]
# Best R2 Score is 0.7960657586543342

# %% [markdown]
# # Using Decision Tree Regressor

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtr_pred=dtr.predict(x_test)

# %%
print('Mean Squared Error:', mse(y_test, dtr_pred))
print('Mean Absolute Error:', mae(y_test, dtr_pred))
print('Root Mean Squared Error:', np.sqrt(mse(y_test, dtr_pred)))
print('R2 Score:', r2_score(y_test, dtr_pred))
# Out:
# Mean Squared Error: 0.2183988467390701
# Mean Absolute Error: 0.3214532221209888
# Root Mean Squared Error: 0.46733162394499916
# R2 Score: 0.5991233525206814

# %% [markdown]
# Best R2 Score is 0.5991233525206814

# %% [markdown]
# # Random Forest Regressor

# %%
rfc=RandomForestRegressor()
rfc.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rfcpred=rfc.predict(x_test)

# %%
print('Mean Squared Error:', mse(y_test, rfcpred))
print('Mean Absolute Error:', mae(y_test, rfcpred))
print('Root Mean Squared Error:', np.sqrt(mse(y_test, rfcpred)))
print('R2 Score:', r2_score(y_test, rfcpred))
# Out:
# Mean Squared Error: 0.12124794354713798
# Mean Absolute Error: 0.2524622389276475
# Root Mean Squared Error: 0.3482067540228621
# R2 Score: 0.7774463105063496

# %% [markdown]
# Best R2 Score is 0.7774463105063496

# %% [markdown]
# # Saving Model

# %%
import joblib
joblib.dump(lr,'Average_two.obj')
# Out:
# ['Average_two.obj']

# %% [markdown]
# # Price range

# %%
X=df.drop(['Price range'], axis=1)
Y=df['Price range']

# %%
X
# Out:
#       Country Code  City   Longitude   Latitude  Average Cost for two  \
# 544       5.220356   117  103.860005   1.282661              5.707110
# 545       5.220356   117  103.859422   1.285477              5.602119
# 546       5.220356   117  103.840360   1.279420              6.216606
# 547       5.220356   117  103.841669   1.280503              4.394449
# 548       5.220356   117  103.853605   1.293221              6.066108
# ...            ...   ...         ...        ...                   ...
# 9271      0.693147   133   83.361377  17.764287              6.398595
# 9272      0.693147   133    0.000000   0.000000              5.993961
# 9273      0.693147   133   83.315281  17.719539              6.398595
# 9274      0.693147   133   83.336840  17.721182              7.313887
# 9275      0.693147   133   83.314942  17.721119              7.244942
#
#       Currency  Has Table booking  Has Online delivery  Aggregate rating  \
# ...

# %%
Y
# Out:
# 544     1.609438
# 545     1.609438
# 546     1.609438
# 547     1.609438
# 548     1.609438
#           ...
# 9271    1.098612
# 9272    1.098612
# 9273    1.098612
# 9274    1.609438
# 9275    1.386294
# Name: Price range, Length: 8441, dtype: float64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y, random_state=42, test_size=.30)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (5908, 13)
# (5908,)
# (2533, 13)
# (2533,)

# %% [markdown]
# # Using Linear Regression

# %%
LR=LinearRegression()
LR.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
LR.coef_
# Out:
# array([ 1.28534673e-01, -2.48097623e-04,  2.29555477e-03, -7.13152265e-03,
#         2.76330400e-01, -5.67831896e-02,  1.48903854e-01, -1.66288630e-02,
#        -3.10539100e-03,  2.14393876e-04,  6.38868266e-03,  1.89511241e-02,
#         2.30236021e-02])

# %%
LR.intercept_
# Out:
# -0.6666805010358967

# %%
LRpred=LR.predict(X_test)
print("Predicted Value", LRpred)
print("Actual Value", Y_test)
# Out:
# Predicted Value [1.21972431 0.67717258 0.77553029 ... 0.53801033 0.82870861 1.13392576]
# Actual Value 943     1.386294
# 3391    0.693147
# 4624    0.693147
# 916     0.693147
# 5117    1.098612
#           ...
# 5798    0.693147
# 3426    0.693147
# 4166    0.693147
# 8271    0.693147
# 6427    1.098612
# Name: Price range, Length: 2533, dtype: float64

# %%
print('Mean Squared Error:', mse(Y_test, LRpred))
print('Mean Absolute Error:', mae(Y_test, LRpred))
print('Root Mean Squared Error:', np.sqrt(mse(Y_test, LRpred)))
print('R2 Score:', r2_score(Y_test, LRpred))
# Out:
# Mean Squared Error: 0.01898471020071043
# Mean Absolute Error: 0.11412190552273348
# Root Mean Squared Error: 0.13778501442722438
# R2 Score: 0.7704504643437381

# %% [markdown]
# Best R2 Score is 0.7704504643437381

# %% [markdown]
# # Using Decision Tree Regressor

# %%
DTR=DecisionTreeRegressor()
DTR.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
DTR_pred=DTR.predict(X_test)

# %%
print('Mean Squared Error:', mse(Y_test, DTR_pred))
print('Mean Absolute Error:', mae(Y_test, DTR_pred))
print('Root Mean Squared Error:', np.sqrt(mse(Y_test, DTR_pred)))
print('R2 Score:', r2_score(Y_test, DTR_pred))
# Out:
# Mean Squared Error: 0.0008540288515386875
# Mean Absolute Error: 0.0028125889347253856
# Root Mean Squared Error: 0.029223772027900292
# R2 Score: 0.9896736940287653

# %% [markdown]
# Best R2 Score is 0.9896736940287653

# %% [markdown]
# # Random Forest Regressor

# %%
RFC=RandomForestRegressor()
RFC.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
RFCpred=RFC.predict(X_test)

# %%
print('Mean Squared Error:', mse(Y_test, RFCpred))
print('Mean Absolute Error:', mae(Y_test, RFCpred))
print('Root Mean Squared Error:', np.sqrt(mse(Y_test, RFCpred)))
print('R2 Score:', r2_score(Y_test, RFCpred))
# Out:
# Mean Squared Error: 0.0005598774671376351
# Mean Absolute Error: 0.003993382518179257
# Root Mean Squared Error: 0.02366173001151089
# R2 Score: 0.9932303621573829

# %% [markdown]
# Best R2 Score is 0.9932303621573829

# %% [markdown]
# # Saving Model

# %%
import joblib
joblib.dump(RFC,'price_range.obj')
# Out:
# ['price_range.obj']
