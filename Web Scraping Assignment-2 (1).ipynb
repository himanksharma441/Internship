# %%
# !pip install selenium

# %%
import selenium                                 
from selenium import webdriver                   
import pandas as pd                              
from selenium.webdriver.common.by import By      
import warnings
warnings.filterwarnings("ignore")
import time

# %%
driver = webdriver.Chrome()

# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.

# %%
driver.get("https://www.naukri.com/")

# %%
skill=driver.find_element(By.CLASS_NAME,"suggestor-input")
skill.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required})
df
# Out:
#                     Title                                           Location  \
# 0            Data Analyst  Bangalore/ Bengaluru, Karnataka, Gurgaon/ Guru...
# 1            Data Analyst                                Bangalore/Bengaluru
# 2            Data Analyst  Bangalore/Bengaluru, Hyderabad/Secunderabad, Pune
# 3            Data Analyst                                Bangalore/Bengaluru
# 4            Data Analyst                                Bangalore/Bengaluru
# 5            Data Analyst                                Bangalore/Bengaluru
# 6            Data Analyst                                Bangalore/Bengaluru
# 7            Data Analyst  Bangalore/Bengaluru, Kolkata, Mumbai, New Delh...
# 8    Data Analyst | HyVee                                Bangalore/Bengaluru
# 9  Data Analyst with ANSR                    Bangalore/ Bengaluru, Karnataka
#
#         Company_name Experience
# 0          Delhivery    1-3 Yrs
# 1        Eastvantage    4-6 Yrs
# ...

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.

# %%
driver.get("https://www.naukri.com/")

# %%
desigination=driver.find_element(By.CLASS_NAME,"suggestor-input")
desigination.send_keys('Data Scientist')

# %%
locate=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/div[1]/div/input")
locate.send_keys('Bangalore')

# %%
Search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
Search.click()

# %%
jobtitle=[]
joblocation=[]
companyname=[]
experiencerequired=[]

# %%
titletags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for a in titletags[0:10]:
    tit=a.text
    jobtitle.append(tit)
    
locationtags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for a in locationtags[0:10]:
    locat=a.text
    joblocation.append(locat)
    
companytags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for a in companytags[0:10]:
    comp=a.text
    companyname.append(comp)
    
experiencetags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for a in experiencetags[0:10]:
    exper=a.text
    experiencerequired.append(exper)

# %%
print(len(jobtitle),len(joblocation),len(companyname),len(experiencerequired))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Title':jobtitle,'Location':joblocation,'Company_name':companyname,'Experience':experiencerequired})
df
# Out:
#                                                Title  \
# 0                            Data Science Specialist
# 1                                     Data Scientist
# 2                                     DATA SCIENTIST
# 3                                     Data Scientist
# 4  ACN - Applied Intelligence - Finance - Data Sc...
# 5                              Senior Data Scientist
# 6                      Sr . Data Scientist / Manager
# 7                                     Data Scientist
# 8                  Data Scientist with Retail Domain
# 9                                     Data Scientist
#
#                                             Location  \
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 1            Bangalore/Bengaluru, Mumbai (All Areas)
# 2                                Bangalore/Bengaluru
# 3  Hybrid - Bangalore/ Bengaluru, Karnataka, Noid...
# 4  Bangalore/Bengaluru, Hyderabad/Secunderabad, P...
# 5                        Bangalore/Bengaluru, Mumbai
# ...

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage as shown below:
#         You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required.
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs

# %%
driver.get("https://www.naukri.com/")

# %%
desig=driver.find_element(By.CLASS_NAME,"suggestor-input")
desig.send_keys('Data Scientist')

# %%
searchbu=driver.find_element(By.CLASS_NAME,"qsbSubmit")
searchbu.click()

# %%
loca=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/p/span[1]")
loca.click()

# %%
salaryfu=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/p/span[1]")
salaryfu.click()

# %%
titlename=[]
locationname=[]
itcompanyname=[]
experienced=[]

# %%
sam=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for bag in sam[0:10]:
    nam=bag.text
    titlename.append(nam)
    
ram=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for bag in ram[0:10]:
    clas=bag.text
    locationname.append(clas)
    
book=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for bag in book[0:10]:
    roll=bag.text
    itcompanyname.append(roll)
    
sachin=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for bag in sachin[0:10]:
    sect=bag.text
    experienced.append(sect)

# %%
print(len(titlename),len(locationname),len(itcompanyname),len(experienced))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Title':titlename,'Location':locationname,'Company_name':itcompanyname,'Experience':experienced})
df
# Out:
#                                                Title  \
# 0                              Junior Data Scientist
# 1                                     Data Scientist
# 2  Data Scientist/ Senior Data Scientist/ Manager...
# 3                                     Data Scientist
# 4                                     Data Scientist
# 5                              Python and ML Trainer
# 6                                             Intern
# 7                          Hiring For Data Scientist
# 8                              Junior Data Scientist
# 9                Associate Data Scientist - ML & NLP
#
#                                             Location  \
# 0  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 1              Gurgaon/Gurugram, Bangalore/Bengaluru
# 2  Noida, Kolkata, Mumbai, Chandigarh, Hyderabad/...
# 3  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 4                                              Noida
# 5  Hyderabad/Secunderabad, New Delhi, Pune, Gurga...
# ...

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
driver.get("https://www.flipkart.com/")

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('sunglasses')

# %%
productsearch=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
productsearch.click()

# %%
brandproduct=[]
branddescription=[]
brandprice=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for bar in brand_tags[0:40]:
    brand=bar.text
    brandproduct.append(brand)
    
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa" or @class="IRpwTa _2-ICcC"]')
for descri in description_tags[0:40]:
    descr=descri.text
    branddescription.append(descr)
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for pr in price_tags[0:40]:
    price=pr.text
    brandprice.append(price)

# %%
print(len(brandproduct),len(branddescription),len(brandprice))
# Out:
# 40 40 40

# %%
df=pd.DataFrame({'Brand':brandproduct,'Description':branddescription,'Price':brandprice})
df
# Out:
#              Brand                                        Description    Price
# 0    VINCENT CHASE             UV Protection Wayfarer Sunglasses (59)     ₹569
# 1           OAKLEY                               Rectangular Sunglass  ₹10,079
# 2        Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...     ₹168
# 3            SDEEP  UV Protection, Others Spectacle Sunglasses (Fr...     ₹185
# 4             SRPM             UV Protection Wayfarer Sunglasses (50)     ₹194
# 5          Styloze  Riding Glasses, Night Vision Wayfarer Sunglass...     ₹183
# 6    Poshh eyewear   UV Protection Rectangular Sunglasses (Free Size)     ₹399
# 7    VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)     ₹949
# 8             SRPM             UV Protection Wayfarer Sunglasses (50)     ₹194
# 9         Fastrack   UV Protection Rectangular Sunglasses (Free Size)     ₹539
# 10   VINCENT CHASE  by Lenskart UV Protection Clubmaster Sunglasse...     ₹949
# ...

# %%
nextpage=driver.find_element(By.CLASS_NAME,"ge-49M")
nextpage.click()

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for bar in brand_tags[0:40]:
    brand=bar.text
    brandproduct.append(brand)
    
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa" or @class="IRpwTa _2-ICcC"]')
for descri in description_tags[0:40]:
    descr=descri.text
    branddescription.append(descr)
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for pr in price_tags[0:40]:
    price=pr.text
    brandprice.append(price)

# %%
print(len(brandproduct),len(branddescription),len(brandprice))
# Out:
# 80 80 80

# %%
df=pd.DataFrame({'Brand':brandproduct,'Description':branddescription,'Price':brandprice})
df
# Out:
#             Brand                                        Description    Price
# 0   VINCENT CHASE             UV Protection Wayfarer Sunglasses (59)     ₹569
# 1          OAKLEY                               Rectangular Sunglass  ₹10,079
# 2       Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...     ₹168
# 3           SDEEP  UV Protection, Others Spectacle Sunglasses (Fr...     ₹185
# 4            SRPM             UV Protection Wayfarer Sunglasses (50)     ₹194
# ..            ...                                                ...      ...
# 75      Elligator   UV Protection, Mirrored Wayfarer Sunglasses (54)     ₹229
# 76    john jacobs             UV Protection Wayfarer Sunglasses (46)   ₹1,979
# 77    john jacobs                UV Protection Round Sunglasses (54)   ₹1,988
# 78           BKGE  Polarized, UV Protection Retro Square Sunglass...     ₹199
# 79      Rich Club          UV Protection Rectangular Sunglasses (52)     ₹395
#
# [80 rows x 3 columns]

# %%
nextpage=driver.find_element(By.CLASS_NAME,"ge-49M")
nextpage.click()

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for bar in brand_tags[0:20]:
    brand=bar.text
    brandproduct.append(brand)
    
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa" or @class="IRpwTa _2-ICcC"]')
for descri in description_tags[0:20]:
    descr=descri.text
    branddescription.append(descr)
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for pr in price_tags[0:20]:
    price=pr.text
    brandprice.append(price)

# %%
print(len(brandproduct),len(branddescription),len(brandprice))
# Out:
# 100 100 100

# %%
df=pd.DataFrame({'Brand':brandproduct,'Description':branddescription,'Price':brandprice})
df
# Out:
#             Brand                                        Description    Price
# 0   VINCENT CHASE             UV Protection Wayfarer Sunglasses (59)     ₹569
# 1          OAKLEY                               Rectangular Sunglass  ₹10,079
# 2       Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...     ₹168
# 3           SDEEP  UV Protection, Others Spectacle Sunglasses (Fr...     ₹185
# 4            SRPM             UV Protection Wayfarer Sunglasses (50)     ₹194
# ..            ...                                                ...      ...
# 95        ROADWAY  UV Protection Retro Square Sunglasses (Free Size)     ₹372
# 96  VINCENT CHASE     Polarized, UV Protection Round Sunglasses (51)     ₹949
# 97  VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)     ₹949
# 98        TryBudy         UV Protection Round Sunglasses (Free Size)     ₹349
# 99      Elligator                UV Protection Round Sunglasses (53)     ₹199
#
# [100 rows x 3 columns]

# %% [markdown]
# Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:
# https://www.flipkart.com/apple-iphone-11-black-64-gb/productreviews/
# itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market
# place=FLIPKART
# As shown in the above page you have to scrape the tick marked attributes. These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100reviews.

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZE3ENS&marketplace=FLIPKART")

# %%
rating=[]
review=[]
fullreview=[]

# %%
start=0
end=10
for pages in range(start,end):
    rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for rat in rating_tags:
        ratig=rat.text
        rating.append(ratig)
    
    review_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for rev in review_tags:
        revi=rev.text
        review.append(revi)
    
    fullreview_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for ful in fullreview_tags:
        fullre=ful.text
        fullreview.append(fullre)
        
    pagenext=driver.find_element(By.CLASS_NAME,"ge-49M")
    pagenext.click()

# %%
print(len(rating),len(review),len(fullreview))
# Out:
# 100 100 100

# %%
df=pd.DataFrame({'Rating':rating,'Review':review,'FullReview':fullreview})
df
# Out:
#    Rating                 Review  \
# 0       5  Mind-blowing purchase
# 1       5         Classy product
# 2       5               Terrific
# 3       5              Wonderful
# 4       5              Must buy!
# ..    ...                    ...
# 95      5              Just wow!
# 96      5       Perfect product!
# 97      5              Fabulous!
# 98      5    Best in the market!
# 99      5      Worth every penny
#
#                                            FullReview
# 0                                        Photos super
# 1   Camera is awesome\nBest battery backup\nA perf...
# 2                                      Very very good
# 3                              This is amazing at all
# 4                                 It’s really awesome
# ..                                                ...
# 95                                  Perfect Product!!
# 96                                         V Good all
# 97                    Super🔥 and good performance 👌❤️
# ...

# %% [markdown]
# Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the
# search field.
# You have to scrape 3 attributes of each sneaker:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
driver.get("https://www.flipkart.com/")

# %%
sneaker=driver.find_element(By.CLASS_NAME,"_3704LK")
sneaker.send_keys('sneakers')

# %%
sneakersearch=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
sneakersearch.click()

# %%
sneakerproduct=[]
sneakerdescription=[]
sneakerprice=[]

# %%
snp_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for sn in snp_tags[0:40]:
    sneak=sn.text
    sneakerproduct.append(sneak)
    
snde_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa" or @class="IRpwTa _2-ICcC"]')
for sdn in snde_tags[0:40]:
    snednp=sdn.text
    sneakerdescription.append(snednp)
    
snpri_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for spn in snpri_tags[0:40]:
    prs=spn.text
    sneakerprice.append(prs)

# %%
print(len(sneakerproduct),len(sneakerdescription),len(sneakerprice))
# Out:
# 40 40 40

# %%
sneakernext=driver.find_element(By.CLASS_NAME,"ge-49M")
sneakernext.click()

# %%
snp_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for sn in snp_tags[0:40]:
    sneak=sn.text
    sneakerproduct.append(sneak)
    
snde_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa" or @class="IRpwTa _2-ICcC"]')
for sdn in snde_tags[0:40]:
    snednp=sdn.text
    sneakerdescription.append(snednp)
    
snpri_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for spn in snpri_tags[0:40]:
    prs=spn.text
    sneakerprice.append(prs)

# %%
print(len(sneakerproduct),len(sneakerdescription),len(sneakerprice))
# Out:
# 80 80 80

# %%
snp_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for sn in snp_tags[0:20]:
    sneak=sn.text
    sneakerproduct.append(sneak)
    
snde_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa" or @class="IRpwTa _2-ICcC"]')
for sdn in snde_tags[0:20]:
    snednp=sdn.text
    sneakerdescription.append(snednp)
    
snpri_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for spn in snpri_tags[0:20]:
    prs=spn.text
    sneakerprice.append(prs)

# %%
print(len(sneakerproduct),len(sneakerdescription),len(sneakerprice))
# Out:
# 100 100 100

# %%
df=pd.DataFrame({'Brand':sneakerproduct,'Description':sneakerdescription,'Price':sneakerprice})
df
# Out:
#           Brand                                        Description   Price
# 0        Airson  Junior Zero1 Sports shoes for Men | Gym Traini...    ₹989
# 1         Sparx  Stylish and Comfirtable Shoes For Mens Sneaker...    ₹764
# 2        BRUTON               Modern Trendy Shoes Sneakers For Men    ₹299
# 3          aadi  Lightweight,Comfort,Summer,Trendy,Walking,Outd...    ₹479
# 4        Kraasa                                 Sneakers For Women    ₹399
# ..          ...                                                ...     ...
# 95         aadi                                   Sneakers For Men    ₹459
# 96  New Balance                              XC72 Sneakers For Men  ₹6,759
# 97  kardam&sons  kardam&sons luxury fashionable Stylish Light W...    ₹549
# 98    FOOTCANDY                                   Sneakers For Men    ₹510
# 99         aadi  Mesh |Lightweight|Comfort|Summer|Trendy|Walkin...    ₹409
#
# [100 rows x 3 columns]

# %% [markdown]
# Q7: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then
# set CPU Type filter to “Intel Core i7”
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
driver.get("https://www.amazon.in/")

# %%
amazon=driver.find_element(By.ID,"twotabsearchtextbox")
amazon.send_keys('Laptop')

# %%
amazonsearch=driver.find_element(By.ID,"nav-search-submit-button")
amazonsearch.click()

# %%
intel=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[2]/ul/span/li/span/a/span")
intel.click()

# %%
laptoptitle=[]
laptoprating=[]
laptopprice=[]

# %%
laptopti_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
for lap in laptopti_tags[0:10]:
    latit=lap.text
    laptoptitle.append(latit)
    
laptoprat_tags=driver.find_elements(By.CLASS_NAME,'a-icon-alt')
for lr in laptoprat_tags[0:10]:
    laprt=lr.text
    laptoprating.append(laprt)
    
laptoppri_tags=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for lp in laptoppri_tags[0:10]:
    lappr=lp.text
    laptopprice.append(lappr)

# %%
print(len(laptoptitle),len(laptoprating),len(laptopprice))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'Title':laptoptitle,'Rating':laptoprating,'Price':laptopprice})
df
# Out:
#                                                Title Rating     Price
# 0  Lenovo ThinkPad E14 Intel Core i7 12th Gen 14"...           93,990
# 1  ASUS ROG Zephyrus G16, 16-inch (40.64 cms) FHD...         1,44,990
# 2  HP Pavilion 14, 11Th Gen Intel Core I7-16Gb Ra...           79,990
# 3  Lenovo IdeaPad Gaming 3 Intel Core i7-12700H 1...           98,500
# 4  Acer Aspire 5 Gaming Laptop Intel Core i7 13th...           80,990
# 5  Dell Inspiron 5430 13th Gen Laptop, Intel i7-1...           86,420
# 6  Lenovo [SmartChoice] IdeaPad Slim 3 Intel Core...           62,990
# 7  Acer Nitro 5 AN515-58 Gaming Laptop 12th Gen I...         1,04,990
# 8  (Renewed) HP Laptop 15s, 12th Gen Intel Core i...           66,663
# 9  Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 1...           80,990

# %% [markdown]
# Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.
# The above task will be done in following steps:
# 1. First get the webpage https://www.azquotes.com/
# 2. Click on Top Quotes
# 3. Than scrap a) Quote b) Author c) Type Of Quotes

# %%
driver.get("https://www.azquotes.com/")

# %%
azquotes=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a")
azquotes.click()

# %%
quotes=[]
author=[]
typeofquotes=[]

# %%
start=0
end=10
for page1 in range(start,end):
    
    quotes_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
    for i in quotes_tags:
        quotes.append(i.text)
    
    author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
    for i in author_tags:
        author.append(i.text)
    
    typeofquotes_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
    for i in typeofquotes_tags:
        typeofquotes.append(i.text)
    
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[3]/li[3]/a')
    next_button.click()

# %%
print(len(quotes),len(author),len(typeofquotes))
# Out:
# 1000 1000 1000

# %%
df=pd.DataFrame({'Quotes':quotes,'Author':author,'Type of Quotes':typeofquotes})
df
# Out:
#                                                 Quotes                 Author  \
# 0    The essence of strategy is choosing what not t...         Michael Porter
# 1    One cannot and must not try to erase the past ...             Golda Meir
# 2    Patriotism means to stand by the country. It d...     Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...         Nelson Mandela
# 4    You have to love a nation that celebrates its ...           Erma Bombeck
# ..                                                 ...                    ...
# 995  When one door closes, another opens; but we of...  Alexander Graham Bell
# 996                   Don't find fault, find a remedy.             Henry Ford
# 997  I used to think the worst thing in life was to...         Robin Williams
# 998  Friends and good manners will carry you where ...        Margaret Walker
# 999  If you want to make a permanent change, stop f...           T. Harv Eker
#
# ...

# %% [markdown]
# Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead,
# Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# 1. First get the webpagehttps://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make theDataFrame.

# %%
driver.get("https://www.jagranjosh.com/")

# %%
gk=driver.find_element(By.XPATH,"/html/body/div/div[1]/div/div[1]/div/div[5]/div/div[1]/header/div[3]/ul/li[3]/a")
gk.click()

# %%
listpm=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a")
listpm.click()

# %%
pmname=[] 
borndead=[]
termofoffice=[] 
remarks=[]

# %%
pmname_tags=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]/p')
for pt in pmname_tags:
    pmma=pt.text
    pmname.append(pmma)
    
borndead_tags=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]/p')
for bd in borndead_tags:
    bode=bd.text
    borndead.append(bode)
    
termofoffice_tags=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]/p[1]')
for tof in termofoffice_tags:
    teofm=tof.text
    termofoffice.append(teofm)
    
remarks_tags=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]/p')
for rm in remarks_tags:
    remk=rm.text
    remarks.append(remk)

# %%
print(len(pmname),len(borndead),len(termofoffice),len(remarks))
# Out:
# 19 19 19 19

# %%
df=pd.DataFrame({'PM Name':pmname,'BornDead':borndead,'Term of Office':termofoffice,'Remarks':remarks})
df
# Out:
#                         PM Name      BornDead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
# 18                Narendra Modi   (born 1950)
#
# ...

# %% [markdown]
# Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e.
# Car name and Price) from https://www.motor1.com/
# This task will be done in following steps:
# 1. First get the webpage https://www.motor1.com/
# 2. Then You have to type in the search bar ’50 most expensive cars’
# 3. Then click on 50 most expensive cars in the world..
# 4. Then scrap the mentioned data and make the dataframe.

# %%
driver.get("https://www.motor1.com/")

# %%
motor=driver.find_element(By.ID,"search_input")
motor.send_keys('50 most expensive cars')

# %%
motorsearch=driver.find_element(By.XPATH,"/html/body/div[10]/div[2]/div/div/div[3]/div/div/div/form/button[1]")
motorsearch.click()

# %%
motornext=driver.find_element(By.XPATH,"/html/body/div[10]/div[9]/div/div[1]/div/div/div[2]/div/div[1]/h3/a")
motornext.click()

# %%
carname=[]
carprice=[]

# %%
carname_tags=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for cr in carname_tags[0:50]:
    carnm=cr.text
    carname.append(carnm)
    
carprice_tags=driver.find_elements(By.TAG_NAME,'strong')
for cp in carprice_tags[0:50]:
    carpi=cp.text
    carprice.append(carpi)

# %%
print(len(carname),len(carprice))
# Out:
# 50 50

# %%
df=pd.DataFrame({'Car Name':carname,'Car Price':carprice})
df
# Out:
#                            Car Name             Car Price
# 0                     De Tomaso P72   Price: $1.3 Million
# 1                 Ferrari LaFerrari   Price: $1.4 Million
# 2                     Pagani Huayra   Price: $1.4 Million
# 3                      McLaren Elva
# 4                       Czinger 21C   Price: $1.7 Million
# 5                     Ferrari Monza   Price: $1.7 Million
# 6                Gordon Murray T.33   Price: $1.7 Million
# 7                 Koenigsegg Gemera   Price: $1.7 Million
# 8                       Zenvo TSR-S   Price: $1.7 Million
# 9                Hennessey Venom F5   Price: $1.7 Million
# 10                  Bentley Bacalar   Price: $1.8 Million
# 11    Hispano Suiza Carmen Boulogne   Price: $1.9 Million
# 12           Bentley Mulliner Batur   Price: $1.9 Million
# 13                     Deus Vayanne   Price: $2.0 Million
# 14                      SSC Tuatara   Price: $2.0 Million
# 15                      Lotus Evija  Price: $2.0 Million*
# ...
